# %% [markdown]
# # 📘 11_tuples.ipynb
#
# ### 🧩 Topic: Tuples in Python

# %% [markdown]
# ## 🧠 1. What are Tuples?
#
# A **tuple** is an ordered, immutable collection of elements.
# Once created, you **cannot modify, add, or remove** elements.
#
# Tuples are often used for **fixed data** — like coordinates, records, or constants.
#
# Example:
# ```python
# person = ("Surendra", 24, "Developer")
# ```

# %% [markdown]
# ### 🧩 Visual Representation
# ```
# person = ("Surendra", 24, "Developer")
# Indexes →   0            1         2
# ```

# %% [markdown]
# ## 🔹 2. Creating Tuples

# %%
# Empty tuple
empty_tuple = ()
print("Empty:", empty_tuple)

# Tuple with elements
numbers = (10, 20, 30, 40)
print("Numbers:", numbers)

# Mixed data types
data = ("Python", 3.11, True, [1, 2, 3])
print("Mixed:", data)

# Tuple without parentheses (implicit tuple)
fruits = "apple", "banana", "cherry"
print("Fruits:", fruits)

# Single-element tuple (needs a comma)
single = ("hello",)
print("Single element:", single)

# %% [markdown]
# ## 🔢 3. Accessing Tuple Elements

# %%
person = ("Surendra", 24, "Developer")

print("Name:", person[0])
print("Age:", person[1])
print("Job:", person[2])

# Negative indexing
print("Last element:", person[-1])

# %% [markdown]
# ## ✳️ 4. Tuple Packing and Unpacking

# %% [markdown]
# ### 🧩 Visual Diagram
#
# ```
# # Packing
# person = ("Surendra", 24, "Developer")
#
# # Unpacking
# name, age, job = person
# ```

# %%
person = ("Surendra", 24, "Developer")

# Unpack tuple
name, age, job = person
print(f"Name: {name}, Age: {age}, Job: {job}")

# %% [markdown]
# ## 🚫 5. Tuple Immutability

# %% [markdown]
# Tuples **cannot be modified** after creation.
#
# ### Example:
# ```python
# t = (1, 2, 3)
# t[0] = 10  # ❌ Error: TypeError
# ```

# %%
t = (1, 2, 3)
try:
    t[0] = 10
except TypeError as e:
    print("Error:", e)

# %% [markdown]
# ## 🧮 6. Tuple Methods

# %%
numbers = (10, 20, 30, 20, 40)

print("Count of 20:", numbers.count(20))
print("Index of 30:", numbers.index(30))
print("Length:", len(numbers))
print("Max:", max(numbers))
print("Min:", min(numbers))

# %% [markdown]
# ## 🧩 7. Nested Tuples and Slicing

# %%
nested = ((1, 2), (3, 4), (5, 6))
print("Nested Tuple:", nested)
print("First inner tuple:", nested[0])
print("Access element:", nested[1][1])

# Slicing
nums = (10, 20, 30, 40, 50)
print("Slice [1:4]:", nums[1:4])

# %% [markdown]
# ## ⚙️ 8. Tuple vs List

# %% [markdown]
# | Feature | List | Tuple |
# |----------|------|--------|
# | Syntax | `[]` | `()` |
# | Mutability | Mutable | Immutable |
# | Performance | Slower | Faster |
# | Use Case | Dynamic data | Fixed data |

# %%
# Example: performance difference
import sys

list_data = [1, 2, 3, 4, 5]
tuple_data = (1, 2, 3, 4, 5)

print("List size:", sys.getsizeof(list_data), "bytes")
print("Tuple size:", sys.getsizeof(tuple_data), "bytes")

# %% [markdown]
# ## 🌍 9. Real-World Examples

# %% [markdown]
# ### 🧭 Example 1: Coordinates
# ```python
# coordinates = (12.97, 77.59)  # Bangalore location
# ```

# %%
coordinates = (12.97, 77.59)
print(f"Latitude: {coordinates[0]}, Longitude: {coordinates[1]}")

# %% [markdown]
# ### 🧾 Example 2: Student Record (Immutable Data)
# Tuples are great for storing data that shouldn’t change.

# %%
student = ("Akhilesh", "CS", 8.5)
print(f"Name: {student[0]}, Dept: {student[1]}, GPA: {student[2]}")

# %% [markdown]
# ## 🧩 10. Beginner-Level Challenges

# %% [markdown]
# ### 1️⃣ Create a tuple of 5 cities and print them using a loop
# ### 2️⃣ Find the length of a tuple
# ### 3️⃣ Convert a tuple into a list and modify it
# ### 4️⃣ Count how many times a specific number appears in a tuple

# %%
# 1️⃣ Loop through tuple
cities = ("Delhi", "Bangalore", "Chennai", "Hyderabad", "Mumbai")
for city in cities:
    print(city)

# %%
# 2️⃣ Length of tuple
nums = (10, 20, 30, 40, 50)
print("Length:", len(nums))

# %%
# 3️⃣ Convert tuple to list
t = (1, 2, 3)
lst = list(t)
lst.append(4)
print("Modified list:", lst)

# %%
# 4️⃣ Count occurrences
t = (1, 2, 3, 2, 4, 2, 5)
print("Count of 2:", t.count(2))

# %% [markdown]
# ## 💪 11. Advanced Challenges

# %% [markdown]
# ### 1️⃣ Merge two tuples
# ### 2️⃣ Check if an element exists in a tuple
# ### 3️⃣ Find common elements between two tuples
# ### 4️⃣ Sort a list of tuples based on the second value

# %%
# 1️⃣ Merge tuples
t1 = (1, 2, 3)
t2 = (4, 5, 6)
merged = t1 + t2
print("Merged:", merged)

# %%
# 2️⃣ Check membership
colors = ("red", "green", "blue")
print("'green' in colors:", "green" in colors)

# %%
# 3️⃣ Common elements
t1 = (1, 2, 3, 4)
t2 = (3, 4, 5, 6)
common = tuple(set(t1) & set(t2))
print("Common elements:", common)

# %%
# 4️⃣ Sort list of tuples
students = [("A", 85), ("B", 90), ("C", 75)]
sorted_students = sorted(students, key=lambda x: x[1], reverse=True)
print("Sorted by marks:", sorted_students)

# %% [markdown]
# ## 🧠 Summary
#
# | Concept | Description |
# |----------|-------------|
# | Tuple | Ordered, immutable collection |
# | Packing | Combine values into tuple |
# | Unpacking | Assign tuple values to variables |
# | Methods | count(), index() |
# | Tuple vs List | Tuples are faster and immutable |
# | Use Cases | Fixed data like coordinates, records |

# %% [markdown]
# ---
# ## ✅ Next Notebook
# 👉 `12_dictionaries.ipynb` — Learn about key-value data structures and dictionary operations.
