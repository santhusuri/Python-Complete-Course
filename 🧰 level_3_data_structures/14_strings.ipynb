# %% [markdown]
# # 📘 14_strings.ipynb
#
# ### 🧩 Topic: Strings in Python — Text Manipulation and Processing

# %% [markdown]
# ## 🧠 1. What are Strings?
#
# A **string** is a sequence of characters enclosed in quotes.
# Strings are **immutable**, meaning once created, they cannot be changed directly.
#
# Example:
# ```python
# name = "Python"
# ```

# %% [markdown]
# ### 🧩 Visual Representation
#
# ```
# Index:   0   1   2   3   4   5
# String:  P   y   t   h   o   n
# Reverse: -6 -5  -4  -3  -2  -1
# ```

# %% [markdown]
# ## 🔹 2. Creating Strings

# %%
# Single, double, triple quotes
s1 = 'Hello'
s2 = "World"
s3 = '''Multiline
String Example'''

print(s1, s2)
print(s3)

# %% [markdown]
# ## ✂️ 3. Indexing and Slicing

# %%
text = "Python"

print("First character:", text[0])
print("Last character:", text[-1])
print("Slice [0:3]:", text[0:3])
print("Reverse:", text[::-1])

# %% [markdown]
# ## 🧱 4. String Immutability

# %%
word = "Hello"
try:
    word[0] = 'Y'
except TypeError as e:
    print("Error:", e)

# %% [markdown]
# ## ✏️ 5. Common String Methods

# %%
text = "  Python Programming  "

print("Upper:", text.upper())
print("Lower:", text.lower())
print("Strip:", text.strip())
print("Replace:", text.replace("Python", "Java"))
print("Split:", text.split())
print("Count of 'm':", text.count("m"))
print("Starts with 'Py':", text.startswith("Py"))
print("Ends with 'ing':", text.endswith("ing"))

# %% [markdown]
# ## 🔡 6. String Formatting

# %% [markdown]
# Python provides multiple ways to format strings:
#
# 1️⃣ **f-strings** — Python 3.6+
# 2️⃣ **`str.format()`**
# 3️⃣ **Percent formatting (`%`)**

# %%
name = "Surendra"
age = 24

# f-string
print(f"My name is {name} and I am {age} years old.")

# format()
print("My name is {} and I am {} years old.".format(name, age))

# % formatting
print("My name is %s and I am %d years old." % (name, age))

# %% [markdown]
# ## 💬 7. Escape Sequences & Raw Strings

# %%
text = "Line1\nLine2\tTabbed"
print("With escape characters:")
print(text)

raw_text = r"Line1\nLine2\tTabbed"
print("\nRaw string (no escape):")
print(raw_text)

# %% [markdown]
# ## 🧩 8. Encoding and Decoding

# %%
msg = "Hello, Python!"
encoded = msg.encode("utf-8")
decoded = encoded.decode("utf-8")

print("Encoded:", encoded)
print("Decoded:", decoded)

# %% [markdown]
# ## 🧮 9. String Operations

# %%
a = "Python"
b = "Programming"

# Concatenation
print(a + " " + b)

# Repetition
print(a * 3)

# Membership
print("'Py' in a:", "Py" in a)
print("'Java' not in a:", "Java" not in a)

# %% [markdown]
# ## 🌍 10. Real-World Project — Password Strength Checker

# %% [markdown]
# This mini project checks password strength based on:
# - Length ≥ 8
# - Contains uppercase and lowercase letters
# - Contains digits
# - Contains special characters

# %%
import re

def check_password_strength(password):
    strength = 0
    remarks = ""

    if len(password) >= 8:
        strength += 1
    if re.search(r"[A-Z]", password):
        strength += 1
    if re.search(r"[a-z]", password):
        strength += 1
    if re.search(r"[0-9]", password):
        strength += 1
    if re.search(r"[!@#$%^&*(),.?":{}|<>]", password):
        strength += 1

    if strength == 5:
        remarks = "Excellent 💪"
    elif 3 <= strength < 5:
        remarks = "Moderate 👍"
    else:
        remarks = "Weak ❌"

    return remarks

# Test
passwords = ["Python123", "python", "Python@2025", "abc"]
for p in passwords:
    print(f"{p}: {check_password_strength(p)}")

# %% [markdown]
# ## 🧩 11. Beginner-Level Challenges

# %% [markdown]
# ### 1️⃣ Count vowels in a string
# ### 2️⃣ Reverse a string without using slicing
# ### 3️⃣ Check if a string is a palindrome
# ### 4️⃣ Replace all spaces with underscores

# %%
# 1️⃣ Count vowels
def count_vowels(s):
    return sum(1 for ch in s.lower() if ch in "aeiou")

print(count_vowels("Python Programming"))

# %%
# 2️⃣ Reverse without slicing
def reverse_string(s):
    rev = ""
    for ch in s:
        rev = ch + rev
    return rev

print(reverse_string("Python"))

# %%
# 3️⃣ Palindrome check
def is_palindrome(s):
    s = s.lower().replace(" ", "")
    return s == s[::-1]

print("madam ->", is_palindrome("madam"))
print("python ->", is_palindrome("python"))

# %%
# 4️⃣ Replace spaces
text = "Python is fun"
print(text.replace(" ", "_"))

# %% [markdown]
# ## 💪 12. Advanced Challenges

# %% [markdown]
# ### 1️⃣ Count frequency of each character in a string
# ### 2️⃣ Find the longest word in a sentence
# ### 3️⃣ Check if two strings are anagrams
# ### 4️⃣ Implement a simple Caesar cipher encryption

# %%
# 1️⃣ Character frequency
from collections import Counter
text = "hello world"
freq = Counter(text)
print(freq)

# %%
# 2️⃣ Longest word
sentence = "Python makes programming fun and easy"
words = sentence.split()
longest = max(words, key=len)
print("Longest word:", longest)

# %%
# 3️⃣ Anagram check
def are_anagrams(s1, s2):
    return sorted(s1.replace(" ", "").lower()) == sorted(s2.replace(" ", "").lower())

print(are_anagrams("listen", "silent"))
print(are_anagrams("hello", "world"))

# %%
# 4️⃣ Caesar cipher
def caesar_encrypt(text, shift):
    result = ""
    for char in text:
        if char.isalpha():
            base = ord('A') if char.isupper() else ord('a')
            result += chr((ord(char) - base + shift) % 26 + base)
        else:
            result += char
    return result

print(caesar_encrypt("HELLO", 3))  # KHOOR

# %% [markdown]
# ## 🧠 Summary

# %% [markdown]
# | Concept | Description |
# |----------|-------------|
# | String | Sequence of characters |
# | Immutability | Cannot modify once created |
# | Slicing | Extract parts of a string |
# | Methods | `upper()`, `split()`, `replace()`, etc. |
# | Formatting | f-strings, `.format()`, `%` |
# | Encoding | Convert to bytes (UTF-8) |
# | Use Cases | Text processing, validation, analysis |

# %% [markdown]
# ---
# ## ✅ Next Notebook
# 👉 `15_oop.ipynb` — Learn Object-Oriented Programming: Classes, Objects, Inheritance, and Polymorphism.
