# %% [markdown]
# # 📘 13_sets.ipynb
#
# ### 🧩 Topic: Sets in Python — Unordered Unique Collections

# %% [markdown]
# ## 🧠 1. What are Sets?
#
# A **set** is an unordered collection of **unique elements**.
# It automatically removes duplicates and supports mathematical operations like union, intersection, and difference.
#
# Example:
# ```python
# fruits = {"apple", "banana", "cherry"}
# ```

# %% [markdown]
# ### 🧩 Visual Representation
# ```
# fruits = {"apple", "banana", "cherry", "banana"}
# ↓ duplicates removed automatically
# fruits = {"apple", "banana", "cherry"}
# ```

# %% [markdown]
# ## 🔹 2. Creating Sets

# %%
# Empty set
s = set()

# Set with items
numbers = {1, 2, 3, 4, 4}
print("Numbers:", numbers)  # duplicates removed

# Convert list to set
unique = set([1, 2, 2, 3, 4])
print("Unique:", unique)

# %% [markdown]
# ## 🔍 3. Accessing and Iterating

# %%
fruits = {"apple", "banana", "cherry"}

print("'banana' in fruits:", "banana" in fruits)

for fruit in fruits:
    print(fruit)

# %% [markdown]
# ## ✏️ 4. Adding and Removing Elements

# %%
fruits = {"apple", "banana"}

fruits.add("cherry")
fruits.update(["mango", "grape"])
print("After add/update:", fruits)

fruits.remove("banana")
fruits.discard("kiwi")  # safe remove
print("After remove/discard:", fruits)

popped = fruits.pop()
print("Popped:", popped)
print("After pop:", fruits)

# %% [markdown]
# ## 🔄 5. Set Operations (with ASCII Visuals)

# %% [markdown]
# ### ➕ Union — All elements from both sets
# ```
#    A = {1, 2, 3, 4}
#    B = {3, 4, 5, 6}
# Result: {1, 2, 3, 4, 5, 6}
#
# ASCII Venn Diagram:
#       ________
#      /        \
#     /   A∪B    \
#    -------------
# ```

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}
print("Union:", A | B)

# %% [markdown]
# ### ✖️ Intersection — Common elements
# ```
# A ∩ B = {3, 4}
#
# ASCII:
#       ________
#      /        \
#     / 3,4  ∩  \
#    -------------
# ```

# %%
print("Intersection:", A & B)

# %% [markdown]
# ### ➖ Difference — Elements in A but not in B
# ```
# A - B = {1, 2}
# ```

# %%
print("A - B:", A - B)
print("B - A:", B - A)

# %% [markdown]
# ### 🔁 Symmetric Difference — Elements in A or B but not both
# ```
# A △ B = {1, 2, 5, 6}
# ```

# %%
print("Symmetric Difference:", A ^ B)

# %% [markdown]
# ## 🧮 6. Set Relations — Subset, Superset, Disjoint

# %%
A = {1, 2, 3}
B = {1, 2, 3, 4, 5}

print("A ⊆ B:", A.issubset(B))
print("B ⊇ A:", B.issuperset(A))
print("Disjoint:", A.isdisjoint({6, 7}))

# %% [markdown]
# ## 🧱 7. Frozen Sets (Immutable Sets)

# %%
frozen = frozenset([1, 2, 3, 3])
print("Frozen set:", frozen)

try:
    frozen.add(4)
except AttributeError as e:
    print("Error:", e)

# %% [markdown]
# ## 🌍 8. Real-World Example — Email Deduplication

# %%
emails = ["a@gmail.com", "b@gmail.com", "a@gmail.com", "c@gmail.com"]
unique_emails = set(emails)
print("Unique Emails:", unique_emails)
print("Total unique:", len(unique_emails))

# %% [markdown]
# ## 🧩 9. Beginner Challenges

# %%
# 1️⃣ Union & Intersection
A, B = {1, 2, 3}, {3, 4, 5}
print("Union:", A | B)
print("Intersection:", A & B)

# %%
# 2️⃣ Difference
A, B = {10, 20, 30}, {20, 40}
print("A - B:", A - B)

# %%
# 3️⃣ Remove duplicates
nums = [1, 2, 2, 3, 4, 4]
unique = list(set(nums))
print("Unique list:", unique)

# %%
# 4️⃣ Disjoint check
set1, set2 = {1, 2}, {3, 4}
print("Are disjoint:", set1.isdisjoint(set2))

# %% [markdown]
# ## 💪 10. Advanced Challenges

# %%
# 1️⃣ Common students
classA = {"Akhilesh", "Surendra", "Yashaswini"}
classB = {"Surendra", "Rahul", "Priya"}
print("Common:", classA & classB)

# %%
# 2️⃣ Exclusive skills
emp1 = {"Python", "Docker", "Git"}
emp2 = {"Python", "AWS", "Kubernetes"}
print("Exclusive:", emp1 ^ emp2)

# %%
# 3️⃣ Frozenset as dictionary key
skills = {
    frozenset({"Python", "ML"}): "Data Scientist",
    frozenset({"Linux", "Networking"}): "SysAdmin"
}
print(skills)

# %% [markdown]
# ## 🧠 Summary

# %% [markdown]
# | Concept | Description |
# |----------|-------------|
# | Set | Unordered, unique elements |
# | Mutable | Yes (`set`) |
# | Immutable | `frozenset` |
# | Operations | Union, Intersection, Difference |
# | Relations | Subset, Superset, Disjoint |
# | Use Cases | Deduplication, membership tests, set logic |

# %% [markdown]
# ---
# ## ✅ Next Notebook
# 👉 `14_strings.ipynb` — Learn about strings, slicing, formatting, and encoding in Python.
