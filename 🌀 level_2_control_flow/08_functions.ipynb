# %% [markdown]
# # 📘 08_functions.ipynb
#
# ### 🧩 Topic: Functions in Python

# %% [markdown]
# ## 🧠 1. Introduction
#
# **Functions** are reusable blocks of code designed to perform a specific task.
# They make programs modular, organized, and easier to maintain.
#
# ### ✅ Advantages of Functions:
# - Code reusability
# - Better readability
# - Easier debugging
# - Reduced redundancy

# %% [markdown]
# ## 🔹 2. Defining a Function
#
# Syntax:
# ```python
# def function_name(parameters):
#     # code block
#     return value
# ```

# %%
# Example: Simple function
def greet():
    print("Hello, Python Learner!")

greet()

# %% [markdown]
# ## 🧮 3. Function Parameters and Arguments

# %%
def add(a, b):
    result = a + b
    return result

print("Sum:", add(5, 10))

# %% [markdown]
# ## 🧩 4. Default Parameters

# %%
def greet(name="Learner"):
    print(f"Hello, {name}!")

greet()       # Uses default value
greet("Surendra")

# %% [markdown]
# ## 🧾 5. Return Statement

# %%
def square(num):
    return num ** 2

print("Square of 4:", square(4))

# %% [markdown]
# ## ✳️ 6. Positional and Keyword Arguments

# %%
def introduce(name, age):
    print(f"My name is {name} and I am {age} years old.")

introduce("Surendra", 24)                  # Positional
introduce(age=25, name="Python Developer") # Keyword

# %% [markdown]
# ## 🧠 7. Variable-Length Arguments — `*args` and `**kwargs`

# %%
def sum_all(*args):
    total = sum(args)
    print("Sum:", total)

sum_all(1, 2, 3, 4, 5)

def display_info(**kwargs):
    for key, value in kwargs.items():
        print(f"{key} : {value}")

display_info(name="Surendra", role="Developer", country="India")

# %% [markdown]
# ## 🧩 8. Docstrings — Documenting Functions

# %%
def multiply(a, b):
    """This function multiplies two numbers and returns the result."""
    return a * b

help(multiply)

# %% [markdown]
# ## 💬 9. Type Hints and Annotations

# %%
def power(base: int, exponent: int) -> int:
    return base ** exponent

print(power(2, 5))

# %% [markdown]
# ## ⚙️ 10. Lambda (Anonymous) Functions

# %%
# Lambda example
square = lambda x: x ** 2
add = lambda a, b: a + b

print("Square of 5:", square(5))
print("Addition:", add(3, 7))

# %% [markdown]
# ## 🧩 11. Functions Inside Functions (Nested Functions)

# %%
def outer_function():
    def inner_function():
        print("Hello from the inner function!")
    inner_function()

outer_function()

# %% [markdown]
# ## 🧮 12. Beginner-Level Challenges

# %% [markdown]
# ### 1️⃣ Write a function to find the factorial of a number
# ### 2️⃣ Create a function that checks if a number is even or odd
# ### 3️⃣ Write a function to return the maximum of three numbers

# %%
# 1️⃣ Factorial Function
def factorial(n):
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

print("Factorial of 5:", factorial(5))

# %%
# 2️⃣ Even or Odd Checker
def even_or_odd(num):
    return "Even" if num % 2 == 0 else "Odd"

print("7 is", even_or_odd(7))

# %%
# 3️⃣ Maximum of Three Numbers
def max_of_three(a, b, c):
    return max(a, b, c)

print("Largest:", max_of_three(12, 7, 19))

# %% [markdown]
# ## 💪 13. Advanced Challenges

# %% [markdown]
# ### 1️⃣ Write a function-based calculator (add, subtract, multiply, divide)
# ### 2️⃣ Create a recursive function to compute Fibonacci sequence
# ### 3️⃣ Build a function that counts vowels in a string

# %%
# 1️⃣ Function-based Calculator
def calculator(a, b, op):
    if op == "+":
        return a + b
    elif op == "-":
        return a - b
    elif op == "*":
        return a * b
    elif op == "/":
        return a / b
    else:
        return "Invalid operation"

print("Result:", calculator(10, 5, '*'))

# %%
# 2️⃣ Recursive Fibonacci Function
def fibonacci(n):
    if n <= 1:
        return n
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

for i in range(8):
    print(fibonacci(i), end=" ")

# %%
# 3️⃣ Count Vowels in a String
def count_vowels(text):
    vowels = "aeiouAEIOU"
    count = sum(1 for char in text if char in vowels)
    return count

print("Vowel count:", count_vowels("Python Programming"))

# %% [markdown]
# ## 🧠 Summary
#
# | Concept | Description |
# |----------|-------------|
# | `def` | Define a new function |
# | Parameters | Inputs to a function |
# | `return` | Sends result back to caller |
# | `*args`, `**kwargs` | Variable-length arguments |
# | Lambda | One-line anonymous functions |
# | Docstring | Function documentation |
# | Recursion | Function calling itself |

# %% [markdown]
# ---
# ## ✅ Next Notebook
# 👉 `09_recursion.ipynb` — Learn how recursion works with base and recursive cases.
