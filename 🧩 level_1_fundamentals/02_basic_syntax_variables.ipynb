# %% [markdown]
# # 📘 02_basic_syntax_variables.ipynb
#
# ### 🧩 Topic: Basic Syntax and Variables

# %% [markdown]
# ## 🧠 1. Python Syntax Basics
#
# Python uses **indentation** and **newlines** to define code structure — not braces `{}` like other languages.
#
# ### ✅ Example:
# ```python
# if True:
#     print("Indented block runs!")  # 4 spaces indentation
# ```
# If you miss indentation, you’ll get an `IndentationError`.

# %%
# Example: Correct indentation
if True:
    print("This block is indented correctly!")

# %%
# Example: Improper indentation (uncomment to test)
# if True:
# print("This will cause an error")

# %% [markdown]
# ## 💬 2. Comments and Naming Conventions
#
# - Single-line comments: start with `#`
# - Multi-line comments: use triple quotes `''' comment '''`
# - Naming variables: use **snake_case** for readability (e.g., `user_name`)

# %%
# Comment example
# This is a single-line comment

'''
This is a multi-line comment
Python ignores comments during execution
'''

user_name = "Surendra"
print("User Name:", user_name)

# %% [markdown]
# ## 🧩 3. Keywords and Identifiers
#
# Python reserves certain words (keywords) that cannot be used as variable names.
#
# ### ✅ Example:
# ```python
# import keyword
# print(keyword.kwlist)
# ```

# %%
import keyword
print(keyword.kwlist)

# %% [markdown]
# ## 🔢 4. Variables and Assignment
#
# Variables are created automatically when you assign a value.
#
# ```python
# x = 10
# y = "Python"
# ```

# %%
x = 10
y = "Python"
z = 3.14

print("x =", x)
print("y =", y)
print("z =", z)

# %% [markdown]
# ## 🔄 5. Dynamic Typing
#
# Python is **dynamically typed** — variable types are decided at runtime.
#
# ```python
# x = 5       # int
# x = "five"  # str
# ```

# %%
x = 5
print("x =", x, "| type:", type(x))

x = "five"
print("x =", x, "| type:", type(x))

# %% [markdown]
# ## 🧮 6. Multiple Assignment & Unpacking
#
# You can assign multiple variables at once.
#
# ```python
# a, b, c = 10, 20, 30
# ```
# You can also swap values without a temporary variable.

# %%
a, b, c = 10, 20, 30
print(a, b, c)

# Swapping values
a, b = b, a
print("After swapping:", a, b)

# %% [markdown]
# ## ⚠️ 7. Variable Naming Rules
#
# ✅ Valid:
# - `name`, `_value`, `user_1`, `total_amount`
#
# ❌ Invalid:
# - `1name` (cannot start with a number)
# - `total-amount` (no hyphens)
# - `class` (keyword)

# %% [markdown]
# ## 🧠 8. Summary
#
# | Concept | Description |
# |----------|-------------|
# | Indentation | Defines blocks of code |
# | Comments | Explain code and improve readability |
# | Variables | Created automatically upon assignment |
# | Dynamic Typing | Variable type changes at runtime |
# | Multiple Assignment | Assign multiple values at once |
# | Naming Rules | Follow snake_case convention |

# %% [markdown]
# ## 💡 Practice Exercises
#
# 1️⃣ Create 3 variables — `name`, `age`, `language` — and print them using f-string.
# 2️⃣ Swap two numbers without using a third variable.
# 3️⃣ Display all Python keywords using the `keyword` module.

# %%
# ✅ Practice Exercise 1
name = "Surendra"
age = 24
language = "Python"
print(f"My name is {name}, I am {age} years old, and I love {language}.")

# %%
# ✅ Practice Exercise 2
a, b = 10, 20
print("Before Swap:", a, b)
a, b = b, a
print("After Swap:", a, b)

# %%
# ✅ Practice Exercise 3
import keyword
print("Python Keywords:", keyword.kwlist)

# %% [markdown]
# ---
# ## ✅ Next Notebook
# 👉 `03_data_types.ipynb` — Learn about numbers, strings, lists, tuples, and dictionaries.
